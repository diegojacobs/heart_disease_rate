# %%
import pandas as pd

# %% [markdown]
# Load train and test data

# %%
train_data = pd.read_csv("Training_values.csv")
test_data = pd.read_csv("Test_values.csv")
classes = pd.read_csv("Training_labels.csv")

# %% [markdown]
# Merge files

# %%
train_data["class"] = classes["heart_disease_mortality_per_100k"]
#train_data.to_csv("train_dataset_with_classes.csv", index = False)

# %%
train_data.head()
# Out:
#    row_id                                         area__rucc  \
# 0       0  Metro - Counties in metro areas of fewer than ...
# 1       1  Metro - Counties in metro areas of fewer than ...
# 2       4  Metro - Counties in metro areas of 1 million p...
# 3       5  Nonmetro - Urban population of 2,500 to 19,999...
# 4       6  Nonmetro - Urban population of 2,500 to 19,999...
#
#                                area__urban_influence  econ__economic_typology  \
# 0  Small-in a metro area with fewer than 1 millio...  Manufacturing-dependent
# 1  Small-in a metro area with fewer than 1 millio...         Mining-dependent
# 2  Large-in a metro area with at least 1 million ...           Nonspecialized
# 3  Noncore adjacent to a small metro with town of...           Nonspecialized
# 4  Noncore not adjacent to a metro/micro area and...           Nonspecialized
#
#    econ__pct_civilian_labor  econ__pct_unemployment  \
# 0                     0.408                   0.057
# ...

# %% [markdown]
# Replace strings with numerical values

# %%
train_data.loc[(train_data['area__rucc']) == "Metro - Counties in metro areas of 1 million population or more", 'area__rucc'] = 1
train_data.loc[(train_data['area__rucc']) == "Metro - Counties in metro areas of 250,000 to 1 million population", 'area__rucc'] = 2
train_data.loc[(train_data['area__rucc']) == "Metro - Counties in metro areas of fewer than 250,000 population", 'area__rucc'] = 3
train_data.loc[(train_data['area__rucc']) == "Nonmetro - Completely rural or less than 2,500 urban population, adjacent to a metro area", 'area__rucc'] = 4
train_data.loc[(train_data['area__rucc']) == "Nonmetro - Completely rural or less than 2,500 urban population, not adjacent to a metro area", 'area__rucc'] = 5
train_data.loc[(train_data['area__rucc']) == "Nonmetro - Urban population of 2,500 to 19,999, adjacent to a metro area", 'area__rucc'] = 6
train_data.loc[(train_data['area__rucc']) == "Nonmetro - Urban population of 2,500 to 19,999, not adjacent to a metro area", 'area__rucc'] = 7
train_data.loc[(train_data['area__rucc']) == "Nonmetro - Urban population of 20,000 or more, adjacent to a metro area", 'area__rucc'] = 8
train_data.loc[(train_data['area__rucc']) == "Nonmetro - Urban population of 20,000 or more, not adjacent to a metro area", 'area__rucc'] = 9

# %%
train_data.loc[(train_data['area__urban_influence']) == "Large-in a metro area with at least 1 million residents or more", 'area__urban_influence'] = 1
train_data.loc[(train_data['area__urban_influence']) == "Micropolitan adjacent to a large metro area", 'area__urban_influence'] = 2
train_data.loc[(train_data['area__urban_influence']) == "Micropolitan adjacent to a small metro area", 'area__urban_influence'] = 3
train_data.loc[(train_data['area__urban_influence']) == "Micropolitan not adjacent to a metro area", 'area__urban_influence'] = 4
train_data.loc[(train_data['area__urban_influence']) == "Noncore adjacent to a large metro area", 'area__urban_influence'] = 5
train_data.loc[(train_data['area__urban_influence']) == "Noncore adjacent to a small metro and does not contain a town of at least 2,500 residents", 'area__urban_influence'] = 6
train_data.loc[(train_data['area__urban_influence']) == "Noncore adjacent to a small metro with town of at least 2,500 residents", 'area__urban_influence'] = 7
train_data.loc[(train_data['area__urban_influence']) == "Noncore adjacent to micro area and contains a town of 2,500-19,999 residents", 'area__urban_influence'] = 8
train_data.loc[(train_data['area__urban_influence']) == "Noncore adjacent to micro area and does not contain a town of at least 2,500 residents", 'area__urban_influence'] = 9
train_data.loc[(train_data['area__urban_influence']) == "Noncore not adjacent to a metro/micro area and contains a town of 2,500  or more residents", 'area__urban_influence'] = 10
train_data.loc[(train_data['area__urban_influence']) == "Noncore not adjacent to a metro/micro area and does not contain a town of at least 2,500 residents", 'area__urban_influence'] = 11
train_data.loc[(train_data['area__urban_influence']) == "Small-in a metro area with fewer than 1 million residents", 'area__urban_influence'] = 12

# %%
train_data.loc[(train_data['econ__economic_typology']) == "Farm-dependent", 'econ__economic_typology'] = 1
train_data.loc[(train_data['econ__economic_typology']) == "Federal/State government-dependent", 'econ__economic_typology'] = 2
train_data.loc[(train_data['econ__economic_typology']) == "Manufacturing-dependent", 'econ__economic_typology'] = 3
train_data.loc[(train_data['econ__economic_typology']) == "Mining-dependent", 'econ__economic_typology'] = 4
train_data.loc[(train_data['econ__economic_typology']) == "Nonspecialized", 'econ__economic_typology'] = 5
train_data.loc[(train_data['econ__economic_typology']) == "Recreation", 'econ__economic_typology'] = 6

# %%
train_data.loc[(train_data['yr']) == "a", 'yr'] = 0
train_data.loc[(train_data['yr']) == "b", 'yr'] = 1

# %% [markdown]
# Replace empty cells with mean of data in the column

# %%
train_data.loc[(train_data['econ__pct_uninsured_adults']).isnull(), 'econ__pct_uninsured_adults'] = train_data['econ__pct_uninsured_adults'].mean()
train_data.loc[(train_data['econ__pct_uninsured_children']).isnull(), 'econ__pct_uninsured_children'] = train_data['econ__pct_uninsured_children'].mean()
train_data.loc[(train_data['demo__pct_female']).isnull(), 'demo__pct_female'] = train_data['demo__pct_female'].mean()
train_data.loc[(train_data['demo__pct_below_18_years_of_age']).isnull(), 'demo__pct_below_18_years_of_age'] = train_data['demo__pct_below_18_years_of_age'].mean()
train_data.loc[(train_data['demo__pct_aged_65_years_and_older']).isnull(), 'demo__pct_aged_65_years_and_older'] = train_data['demo__pct_aged_65_years_and_older'].mean()
train_data.loc[(train_data['demo__pct_hispanic']).isnull(), 'demo__pct_hispanic'] = train_data['demo__pct_hispanic'].mean()
train_data.loc[(train_data['demo__pct_non_hispanic_white']).isnull(), 'demo__pct_non_hispanic_white'] = train_data['demo__pct_non_hispanic_white'].mean()
train_data.loc[(train_data['demo__pct_american_indian_or_alaskan_native']).isnull(), 'demo__pct_american_indian_or_alaskan_native'] = train_data['demo__pct_american_indian_or_alaskan_native'].mean()
train_data.loc[(train_data['demo__pct_asian']).isnull(), 'demo__pct_asian'] = train_data['demo__pct_asian'].mean()
train_data.loc[(train_data['health__pct_adult_obesity']).isnull(), 'health__pct_adult_obesity'] = train_data['health__pct_adult_obesity'].mean()
train_data.loc[(train_data['health__pct_adult_smoking']).isnull(), 'health__pct_adult_smoking'] = train_data['health__pct_adult_smoking'].mean()
train_data.loc[(train_data['health__pct_diabetes']).isnull(), 'health__pct_diabetes'] = train_data['health__pct_diabetes'].mean()
train_data.loc[(train_data['health__pct_low_birthweight']).isnull(), 'health__pct_low_birthweight'] = train_data['health__pct_low_birthweight'].mean()
train_data.loc[(train_data['health__pct_excessive_drinking']).isnull(), 'health__pct_excessive_drinking'] = train_data['health__pct_excessive_drinking'].mean()
train_data.loc[(train_data['health__pct_physical_inacticity']).isnull(), 'health__pct_physical_inacticity'] = train_data['health__pct_physical_inacticity'].mean()
train_data.loc[(train_data['health__air_pollution_particulate_matter']).isnull(), 'health__air_pollution_particulate_matter'] = train_data['health__air_pollution_particulate_matter'].mean()
train_data.loc[(train_data['health__homicides_per_100k']).isnull(), 'health__homicides_per_100k'] = train_data['health__homicides_per_100k'].mean()
train_data.loc[(train_data['health__motor_vehicle_crash_deaths_per_100k']).isnull(), 'health__motor_vehicle_crash_deaths_per_100k'] = train_data['health__motor_vehicle_crash_deaths_per_100k'].mean()
train_data.loc[(train_data['health__pop_per_dentist']).isnull(), 'health__pop_per_dentist'] = train_data['health__pop_per_dentist'].mean()
train_data.loc[(train_data['health__pop_per_primary_care_physician']).isnull(), 'health__pop_per_primary_care_physician'] = train_data['health__pop_per_primary_care_physician'].mean()

# %% [markdown]
# Replace values for the classes for 3 classes:
#
# 101 - 250 = 0 -> Low
# 251 - 400 = 1 -> Middle
# 401 - 550 = 2 -> High

# %%
for i in range(0,len(train_data)):
    if(train_data.iloc[i,34] < 251):
        train_data.iloc[i,34] = 0
    elif(train_data.iloc[i,34] > 250 and train_data.iloc[i,34] < 401):
        train_data.iloc[i,34] = 1
    else:
        train_data.iloc[i,34] = 2

# %%
train_data.head()
# Out:
#    row_id  area__rucc  area__urban_influence  econ__economic_typology  \
# 0       0           3                     12                        3
# 1       1           3                     12                        4
# 2       4           1                      1                        5
# 3       5           6                      7                        5
# 4       6           7                     10                        5
#
#    econ__pct_civilian_labor  econ__pct_unemployment  \
# 0                     0.408                   0.057
# 1                     0.556                   0.039
# 2                     0.541                   0.057
# 3                     0.500                   0.061
# 4                     0.471                   0.050
#
#    econ__pct_uninsured_adults  econ__pct_uninsured_children  demo__pct_female  \
# 0                       0.254                         0.066             0.516
# ...

# %%
train_data.to_csv("preprocessed_data.csv",index = False)
